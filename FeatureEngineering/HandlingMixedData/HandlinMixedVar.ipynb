# %% [markdown]
# <a href="https://colab.research.google.com/github/astrovishalthakur/MachineLearning/blob/main/FeatureEngineering/HandlingMixedData/HandlinMixedVar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/astrovishalthakur/100-days-of-machine-learning/main/day33-handling-mixed-variables/titanic.csv")

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %% [markdown]
# #### We can see mixed data right out of the bet.

# %%
df.number.unique()
# Out:
# array(['5', '3', '6', 'A', '2', '1', '4'], dtype=object)

# %%
df.number.value_counts()
# Out:
# A    139
# 6    131
# 1    129
# 2    126
# 4    126
# 5    123
# 3    117
# Name: number, dtype: int64

# %%
fig = df.number.value_counts().plot.bar()
fig.set_title("Passengers travelling with")
# Out:
# Text(0.5, 1.0, 'Passengers travelling with')

# %%
# extract numerical part
df["number_numerical"] = pd.to_numeric(df.number, errors="coerce", downcast="integer")

#extracting categorical part
df["number_categorical"] = np.where(df["number_numerical"].isnull(), df.number, np.nan)
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical number_categorical
# 0   NaN         A/5 21171      5         0               5.0                NaN
# 1   C85          PC 17599      3         1               3.0                NaN
# 2   NaN  STON/O2. 3101282      6         1               6.0                NaN
# 3  C123            113803      3         1               3.0                NaN
# 4   NaN            373450      A         0               NaN                  A

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df["cabin_num"] = df.Cabin.str.extract('(\d+)') # Captures the numerical part
df["cabin_cat"] = df.Cabin.str[0] # captures the first letter

df.head()
# Out:
#   Cabin            Ticket number  ...  number_categorical  cabin_num cabin_cat
# 0   NaN         A/5 21171      5  ...                 NaN        NaN       NaN
# 1   C85          PC 17599      3  ...                 NaN         85         C
# 2   NaN  STON/O2. 3101282      6  ...                 NaN        NaN       NaN
# 3  C123            113803      3  ...                 NaN        123         C
# 4   NaN            373450      A  ...                   A        NaN       NaN
#
# [5 rows x 8 columns]

# %%
df.cabin_cat.value_counts().plot(kind="bar")

# %%
# extract the last bit of ticket as number

df["ticket_num"] = pd.to_numeric(df.Ticket.apply(lambda x: x.split()[-1]), errors="coerce", downcast="integer")

# extract the first part of ticket as category

df["ticket_cat"] = df.Ticket.apply(lambda s: s.split()[0])

df["ticket_cat"] = np.where(df.ticket_cat.str.isdigit(), np.nan, df.ticket_cat)

df.head(20)
# Out:
#    Cabin            Ticket number  ...  cabin_cat  ticket_num ticket_cat
# 0    NaN         A/5 21171      5  ...        NaN     21171.0        A/5
# 1    C85          PC 17599      3  ...          C     17599.0         PC
# 2    NaN  STON/O2. 3101282      6  ...        NaN   3101282.0   STON/O2.
# 3   C123            113803      3  ...          C    113803.0        NaN
# 4    NaN            373450      A  ...        NaN    373450.0        NaN
# 5    NaN            330877      2  ...        NaN    330877.0        NaN
# 6    E46             17463      2  ...          E     17463.0        NaN
# 7    NaN            349909      5  ...        NaN    349909.0        NaN
# 8    NaN            347742      1  ...        NaN    347742.0        NaN
# 9    NaN            237736      A  ...        NaN    237736.0        NaN
# 10    G6           PP 9549      1  ...          G      9549.0         PP
# 11  C103            113783      1  ...          C    113783.0        NaN
# ...

# %%
df.cabin_cat.fillna("missing", inplace=True)
df.cabin_num.fillna(0, inplace=True)

# %%
df.head()
# Out:
#   Cabin            Ticket number  ...  cabin_cat  ticket_num ticket_cat
# 0   NaN         A/5 21171      5  ...    missing     21171.0        A/5
# 1   C85          PC 17599      3  ...          C     17599.0         PC
# 2   NaN  STON/O2. 3101282      6  ...    missing   3101282.0   STON/O2.
# 3  C123            113803      3  ...          C    113803.0        NaN
# 4   NaN            373450      A  ...    missing    373450.0        NaN
#
# [5 rows x 10 columns]
